# %%
import pandas as pd
import numpy as np
import timeit

from matplotlib import pyplot as plt
from matplotlib import rcParams
plt.style.use('ggplot')
rcParams['figure.figsize'] = (20.0, 10.0)
from matplotlib import colors

import scipy.stats

# %%
credible_authors = pd.read_csv('data/authors-scientific-atleast-15-year_extended.csv', encoding='utf-8')

# %%
credible_authors = credible_authors.set_index('start_year')

# %%
1973-1970//3
# Out:
# 1317

# %%
fig, ax = plt.subplots(nrows=12, ncols=3, sharex=False, sharey=True, figsize=(16,32))
for year in range(1970, 2004):
    data = credible_authors.loc[year]
    x = data['early_career_prod']
    y = data['final_citation_count']
    axes = ax[(year-1970)//3,year%1970%3]
    axes.scatter(x, y)
    fit = np.polyfit(x, y, deg=1)
    axes.plot(x, fit[0] * x + fit[1], color='red')
    axes.set_title("Cohort: " + str(year))
    # plt.xlim(0, 50)
    # plt.ylim(0,200)
    slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(x, y)
#     print("R squared: ", r_value)
    #     print(slope, intercept)
plt.xlabel('Early Career Productivity')
plt.ylabel('Final Success')
plt.show()

# %%
credible_authors.head()
# Out:
#                author  start_year  end_year  total_num_pub  career_length  \
# 0          a min tjoa        1979      2017            191             38
# 1          a-xing zhu        1998      2017             22             19
# 2  a. a. (louis) beex        1980      2016             31             36
# 3    a. a. abouelsoud        1996      2016             10             20
# 4          a. a. ball        1988      2006              5             18
#
#    early_career_prod  early_career_qual  final_citation_count
# 0                  1                  0                  2587
# 1                  1                  0                   346
# 2                  2                  1                   397
# 3                  3                  6                    16
# 4                  2                 63                   192
